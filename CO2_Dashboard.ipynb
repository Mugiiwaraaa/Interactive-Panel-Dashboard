# %%
import pandas as pd
import numpy as np
import panel as pn 
pn.extension('tabulator') #interactive tables

import hvplot.pandas # interactive dataframes
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
#setting up cache data for better performance 
if 'data' not in pn.state.cache.keys():
    df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
    pn.state.cache['data'] = df.copy()
    
else:
    df = pn.state.cache['data']

# %%
df.sample(10)
# Out:
#                              country  year iso_code    population  \
# 11500                           Iran  1947      IRN  1.648748e+07
# 6892                        Eswatini  1984      SWZ  6.752400e+05
# 22762                     Tajikistan  1898      TJK  9.431580e+05
# 12001                          Italy  1931      ITA  4.068156e+07
# 25638                          World  1911      NaN  1.804921e+09
# 4082                          Canada  1815      CAN  7.223880e+05
# 24703  Upper-middle-income countries  1852      NaN  5.219006e+08
# 23547                         Turkey  1976      TUR  4.018956e+07
# 12303                          Japan  2009      JPN  1.285552e+08
# 20357                         Serbia  1910      SRB  2.946289e+06
#
#                 gdp  cement_co2  cement_co2_per_capita       co2  \
# 11500           NaN       0.022                  0.001    63.468
# 6892   1.990646e+09         NaN                    NaN     0.333
# 22762           NaN         NaN                    NaN     0.195
# 12001  1.866570e+11       1.519                  0.037    34.173
# 25638           NaN       0.148                  0.000  3082.462
# 4082            NaN         NaN                    NaN     0.004
# 24703           NaN         NaN                    NaN       NaN
# 23547  2.533924e+11       5.850                  0.146    73.359
# 12303  4.287890e+12      25.308                  0.197  1163.213
# 20357           NaN         NaN                    NaN     0.597
#
#        co2_growth_abs  co2_growth_prct  ...  share_global_cumulative_oil_co2  \
# 11500           3.235             5.37  ...                             3.08
# 6892            0.062            22.97  ...                              NaN
# 22762           0.021            12.15  ...                             0.18
# 12001          -5.377           -13.60  ...                             0.34
# 25638          54.873             1.81  ...                           100.00
# 4082            0.000             0.00  ...                              NaN
# 24703             NaN             0.00  ...                              NaN
# 23547           7.940            12.14  ...                             0.26
# 12303         -69.101            -5.61  ...                             5.92
# 20357          -0.006            -1.06  ...                              NaN
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 11500                                NaN                       NaN
# 6892                                 NaN                       NaN
# 22762                                NaN                       NaN
# 12001                                NaN                       NaN
# 25638                                NaN                       NaN
# 4082                                 NaN                       NaN
# 24703                                NaN                       NaN
# 23547                                NaN                       NaN
# 12303                                3.2                      0.14
# 20357                                NaN                       NaN
#
#        share_global_gas_co2  share_global_oil_co2  share_global_other_co2  \
# 11500                   NaN                  5.15                     NaN
# 6892                    NaN                   NaN                     NaN
# 22762                   NaN                  0.24                     NaN
# 12001                  0.02                  0.39                     NaN
# 25638                100.00                100.00                     NaN
# 4082                    NaN                   NaN                     NaN
# 24703                   NaN                   NaN                     NaN
# 23547                   NaN                  0.51                     NaN
# 12303                  3.51                  4.69                     3.4
# 20357                   NaN                   NaN                     NaN
#
#        total_ghg  total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 11500        NaN                       NaN        NaN              NaN
# 6892         NaN                       NaN        NaN              NaN
# 22762        NaN                       NaN        NaN              NaN
# 12001        NaN                       NaN        NaN              NaN
# 25638        NaN                       NaN        NaN              NaN
# 4082         NaN                       NaN        NaN              NaN
# 24703        NaN                       NaN        NaN              NaN
# 23547        NaN                       NaN        NaN              NaN
# 12303     1078.7                   1176.71    199.937            17.19
# 20357        NaN                       NaN        NaN              NaN
#
# [10 rows x 60 columns]

# %%
#filtering dataset for 'world'

# %%
df[df['country'] == 'World']
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 25477   World  1750      NaN  7.456645e+08           NaN         NaN
# 25478   World  1751      NaN           NaN           NaN         NaN
# 25479   World  1752      NaN           NaN           NaN         NaN
# 25480   World  1753      NaN           NaN           NaN         NaN
# 25481   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 25743   World  2016      NaN  7.464335e+09  1.071343e+14    1478.758
# 25744   World  2017      NaN  7.548173e+09  1.104307e+14    1500.493
# 25745   World  2018      NaN  7.631081e+09  1.136302e+14    1566.740
# 25746   World  2019      NaN  7.713458e+09           NaN    1608.472
# 25747   World  2020      NaN  7.794789e+09           NaN    1626.371
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 25477                    NaN      9.351             NaN              NaN  ...
# 25478                    NaN      9.351           0.000             0.00  ...
# 25479                    NaN      9.354           0.004             0.04  ...
# 25480                    NaN      9.354           0.000             0.00  ...
# 25481                    NaN      9.358           0.004             0.04  ...
# ...                      ...        ...             ...              ...  ...
# 25743                  0.198  35452.461         -43.947            -0.12  ...
# 25744                  0.199  35925.738         473.278             1.33  ...
# 25745                  0.205  36646.141         720.402             2.01  ...
# 25746                  0.208  36702.504          56.363             0.15  ...
# 25747                  0.209  34807.258       -1895.244            -5.16  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 25477                              NaN                                NaN
# 25478                              NaN                                NaN
# 25479                              NaN                                NaN
# 25480                              NaN                                NaN
# 25481                              NaN                                NaN
# ...                                ...                                ...
# 25743                            100.0                              80.03
# 25744                            100.0                              80.75
# 25745                            100.0                              81.41
# 25746                            100.0                              82.03
# 25747                            100.0                              82.60
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 25477                       NaN                   NaN                   NaN
# 25478                       NaN                   NaN                   NaN
# 25479                       NaN                   NaN                   NaN
# 25480                       NaN                   NaN                   NaN
# 25481                       NaN                   NaN                   NaN
# ...                         ...                   ...                   ...
# 25743                     100.0                 100.0                 100.0
# 25744                     100.0                 100.0                 100.0
# 25745                     100.0                 100.0                 100.0
# 25746                     100.0                 100.0                 100.0
# 25747                     100.0                 100.0                 100.0
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 25477                     NaN        NaN                       NaN        NaN
# 25478                     NaN        NaN                       NaN        NaN
# 25479                     NaN        NaN                       NaN        NaN
# 25480                     NaN        NaN                       NaN        NaN
# 25481                     NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 25743                   100.0  47531.680                 46264.070       -0.0
# 25744                   100.0  48251.879                 47031.820        0.0
# 25745                   100.0  49368.039                 47980.469       -0.0
# 25746                   100.0  49758.230                 48116.559        0.0
# 25747                   100.0        NaN                       NaN        0.0
#
#        trade_co2_share
# 25477              NaN
# 25478              NaN
# 25479              NaN
# 25480              NaN
# 25481              NaN
# ...                ...
# 25743             -0.0
# 25744              0.0
# 25745             -0.0
# 25746              0.0
# 25747              0.0
#
# [271 rows x 60 columns]

# %% [markdown]
# # Minor Data Preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df.fillna(0,inplace=True)
df['gdp_per_capita']=np.where(df['population']!=0, df['gdp']/df['population'],0) #set 0 where population is 0

# %%
df = df[ ['gdp_per_capita'] + [ col for col in df.columns if col != 'gdp_per_capita' ] ] #bringing it to the front
df
# Out:
#        gdp_per_capita      country  year iso_code  population           gdp  \
# 0            0.000000  Afghanistan  1949      AFG   7624058.0  0.000000e+00
# 1         1215.332543  Afghanistan  1950      AFG   7752117.0  9.421400e+09
# 2         1236.236369  Afghanistan  1951      AFG   7840151.0  9.692280e+09
# 3         1262.264378  Afghanistan  1952      AFG   7935996.0  1.001733e+10
# 4         1322.255925  Afghanistan  1953      AFG   8039684.0  1.063052e+10
# ...               ...          ...   ...      ...         ...           ...
# 26003     1494.033433     Zimbabwe  2016      ZWE  14030338.0  2.096179e+10
# 26004     1541.648846     Zimbabwe  2017      ZWE  14236599.0  2.194784e+10
# 26005     1573.214825     Zimbabwe  2018      ZWE  14438812.0  2.271535e+10
# 26006        0.000000     Zimbabwe  2019      ZWE  14645473.0  0.000000e+00
# 26007        0.000000     Zimbabwe  2020      ZWE  14862927.0  0.000000e+00
#
#        cement_co2  cement_co2_per_capita     co2  co2_growth_abs  ...  \
# 0           0.000                  0.000   0.015           0.000  ...
# 1           0.000                  0.000   0.084           0.070  ...
# 2           0.000                  0.000   0.092           0.007  ...
# 3           0.000                  0.000   0.092           0.000  ...
# 4           0.000                  0.000   0.106           0.015  ...
# ...           ...                    ...     ...             ...  ...
# 26003       0.639                  0.046  10.738          -1.488  ...
# 26004       0.678                  0.048   9.582          -1.156  ...
# 26005       0.697                  0.048  11.854           2.273  ...
# 26006       0.697                  0.048  10.949          -0.905  ...
# 26007       0.697                  0.047  10.531          -0.418  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 0                                 0.00                                0.0
# 1                                 0.00                                0.0
# 2                                 0.00                                0.0
# 3                                 0.00                                0.0
# 4                                 0.00                                0.0
# ...                                ...                                ...
# 26003                             0.02                                0.0
# 26004                             0.02                                0.0
# 26005                             0.02                                0.0
# 26006                             0.02                                0.0
# 26007                             0.03                                0.0
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 0                           0.0                   0.0                  0.00
# 1                           0.0                   0.0                  0.00
# 2                           0.0                   0.0                  0.00
# 3                           0.0                   0.0                  0.00
# 4                           0.0                   0.0                  0.00
# ...                         ...                   ...                   ...
# 26003                       0.0                   0.0                  0.03
# 26004                       0.0                   0.0                  0.03
# 26005                       0.0                   0.0                  0.03
# 26006                       0.0                   0.0                  0.03
# 26007                       0.0                   0.0                  0.03
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         0.0       0.00                      0.00      0.000
# 1                         0.0       0.00                      0.00      0.000
# 2                         0.0       0.00                      0.00      0.000
# 3                         0.0       0.00                      0.00      0.000
# 4                         0.0       0.00                      0.00      0.000
# ...                       ...        ...                       ...        ...
# 26003                     0.0     115.92                     28.53      1.415
# 26004                     0.0     115.59                     28.30      1.666
# 26005                     0.0     118.22                     30.83      1.308
# 26006                     0.0     117.96                     30.53      1.473
# 26007                     0.0       0.00                      0.00      0.000
#
#        trade_co2_share
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# ...                ...
# 26003            13.18
# 26004            17.39
# 26005            11.04
# 26006            13.45
# 26007             0.00
#
# [26008 rows x 61 columns]

# %%
df.describe()
# Out:
#        gdp_per_capita          year    population           gdp    cement_co2  \
# count    26008.000000  26008.000000  2.600800e+04  2.600800e+04  26008.000000
# mean      4521.463491   1952.169525  8.571653e+07  1.496457e+11      7.722004
# std       9321.395656     54.562304  3.904361e+08  1.579427e+12     59.280931
# min          0.000000   1750.000000  0.000000e+00  0.000000e+00      0.000000
# 25%          0.000000   1923.000000  7.114042e+05  0.000000e+00      0.000000
# 50%        891.814229   1966.000000  4.381048e+06  8.155754e+08      0.000000
# 75%       4776.488810   1994.000000  1.845051e+07  3.325215e+10      0.549000
# max     146405.456571   2020.000000  7.794789e+09  1.136302e+14   1626.371000
#
#        cement_co2_per_capita           co2  co2_growth_abs  co2_growth_prct  \
# count           26008.000000  26008.000000    26008.000000     26008.000000
# mean                0.054223    309.853178        5.962515        20.511003
# std                 0.116990   1634.911262       59.485126       687.928193
# min                 0.000000      0.000000    -1895.244000       -99.640000
# 25%                 0.000000      0.377000       -0.004000        -0.230000
# 50%                 0.000000      4.277000        0.040000         3.240000
# 75%                 0.064000     42.677000        1.026000        10.260000
# max                 2.738000  36702.504000     1736.258000    102318.508000
#
#        co2_per_capita  ...  share_global_cumulative_oil_co2  \
# count    26008.000000  ...                     26008.000000
# mean         3.803137  ...                         2.989482
# std         14.173073  ...                        12.335423
# min          0.000000  ...                         0.000000
# 25%          0.150000  ...                         0.000000
# 50%          0.987000  ...                         0.030000
# 75%          4.203250  ...                         0.360000
# max        748.639000  ...                       100.000000
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# count                       26008.000000              26008.000000
# mean                            1.480002                  1.226080
# std                            10.082368                  7.036245
# min                             0.000000                  0.000000
# 25%                             0.000000                  0.000000
# 50%                             0.000000                  0.000000
# 75%                             0.000000                  0.000000
# max                           100.000000                100.000000
#
#        share_global_gas_co2  share_global_oil_co2  share_global_other_co2  \
# count          26008.000000          26008.000000            26008.000000
# mean               2.369111              2.976808                1.548535
# std               12.593675             12.149225               10.528717
# min                0.000000              0.000000                0.000000
# 25%                0.000000              0.000000                0.000000
# 50%                0.000000              0.035000                0.000000
# 75%                0.050000              0.390000                0.000000
# max              100.000000            100.000000              100.000000
#
#           total_ghg  total_ghg_excluding_lucf     trade_co2  trade_co2_share
# count  26008.000000              26008.000000  26008.000000     26008.000000
# mean     182.400119                176.984359     -1.279523         3.399291
# std     1758.524766               1725.463962    104.042085        19.677623
# min     -186.550000                  0.000000  -2233.000000       -96.760000
# 25%        0.000000                  0.000000      0.000000         0.000000
# 50%        0.000000                  0.000000      0.000000         0.000000
# 75%        0.000000                  0.000000      0.000000         0.000000
# max    49758.230000              48116.559000   2047.575000       366.150000
#
# [8 rows x 59 columns]

# %%
#make the data pipeline interactive  #can use it to manipulate with hvplot and panel
idf = df.interactive()

# %% [markdown]
# # 1st Visualization - CO2 Emissions Over Time by Geographical Region

# %%
#Panel widget to go through different years 
year_slider = pn.widgets.IntSlider(name='Year', start=1750, end=2020, step=5, value = 2015 , bar_color='darkgreen')
year_slider
# Out:
# IntSlider(bar_color='darkgreen', end=2020, name='Year', start=1750, step=5, value=2015)

# %%
#Radio bUtton widgets for CO2 measures 
yaxis_co2 = pn.widgets.RadioButtonGroup(name = 'Y-axis',
                                        options = ['co2','co2_per_capita'], #values 
                                        button_type = 'success') # theme

# %%
#connecting datapipeline and the widgets
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica'] #places to be considered 

co2_pipeline = (
    idf[ (idf.year <= year_slider) & 
         (idf.country.isin(continents))
       ]
    .groupby(['year','country'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='1005'>
#   <div class="bk-root" id="c5d0509b-e6d7-4c12-bf17-28c2438f48dc" data-root-id="1005"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"9c01b61c-2c52-4b13-a9e6-11864eae6ea5":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"client_comm_id":"caef042b4767432a9b983595a473944f","comm_id":"0852d98a0cbd4e8ba04acc663ec29c01","plot_id":"1005"},"id":"1014","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1013"}],"margin":[0,0,0,0],"name":"Row03033"},"id":"1012","type":"Row"},{"attributes":{"active":0,"button_type":"success","labels":["co2","co2_per_capita"],"margin":[5,10,5,10]},"id":"1010","type":"RadioButtonGroup"},{"attributes":{"children":[{"id":"1007"},{"id":"1012"}],"margin":[0,0,0,0],"name":"Column03112"},"id":"1006","type":"Column"},{"attributes":{"children":[{"id":"1006"}],"margin":[0,0,0,0],"name":"Row03113"},"id":"1005","type":"Row"},{"attributes":{"children":[{"id":"1008"},{"id":"1011"}],"margin":[0,0,0,0],"name":"Row03111"},"id":"1007","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer03110","sizing_mode":"stretch_width"},"id":"1011","type":"Spacer"},{"attributes":{"children":[{"id":"1009"},{"id":"1010"}],"margin":[0,0,0,0],"name":"Column03028"},"id":"1008","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame03108","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n ...

# %%
#plotting 
co2_plot = co2_pipeline.hvplot(x= 'year', y= yaxis_co2 , by='country' , line_width=2, title="CO2 emissions by geographical region")
co2_plot
# Out:
# <div id='1015'>
#   <div class="bk-root" id="26ca9c66-67ad-411f-b494-0b599800b9ac" data-root-id="1015"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c1a55580-b2fc-4eae-9aed-6dd468206098":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"data":{"co2":{"__ndarray__":"...","dtype":"float64","order":"little","shape":[266]},"country":["Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe" ...

# %% [markdown]
# # 2nd visualization - Table - CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='1502'>
#   <div class="bk-root" id="24dccfe0-ed5f-433c-8339-a92b9b2aaf38" data-root-id="1502"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"8c098dca-a695-4853-be63-b9dfa119889d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"indices":[]},"id":"1511","type":"Selection"},{"attributes":{"format":"0,0.0[00000]","text_align":"right"},"id":"1528","type":"NumberFormatter"},{"attributes":{},"id":"1523","type":"StringFormatter"},{"attributes":{},"id":"1535","type":"UnionRenderers"},{"attributes":{"children":[{"id":"1503"}],"margin":[0,0,0,0],"name":"Row04203"},"id":"1502","type":"Row"},{"attributes":{"editor":{"id":"1514"},"field":"index","formatter":{"id":"1512"},"title":"index","width":0},"id":"1515","type":"TableColumn"},{"attributes":{"editor":{"id":"1529"},"field":"co2","formatter":{"id":"1528"},"title":"co2","width":0},"id":"1530","type":"TableColumn"},{"attributes":{"children":[{"id":"1504"},{"id":"1509"}],"margin":[0,0,0,0],"name":"Column04202"},"id":"1503","type":"Column"},{"attributes":{"text_align":"right"},"id":"1518","type":"NumberFormatter"},{"attributes":{"client_comm_id":"1948476032134b71882b92ba578dbdcf","comm_id":"be555afcde93455580ab626248d10fa1","plot_id":"1502"},"id":"1541","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1505"},{"id":"1508"}],"margin":[0,0,0,0],"name":"Row04201"},"id":"1504","type":"Row"},{"attributes":{},"id":"1514","type":"CellEditor"},{"attributes":{"data":{"co2":{"__ndarray__":"wcqhRbazIkDByqFFtrMiQMHKoUW2syJAwcqhRbazIkBoke18P7UiQGiR7Xw/tSJAaJHtfD+1IkBoke18P7UiQJ7vp8ZLtyJAnu+nxku3IkA=","dtype":"float64","order":"little","shape":[10]},"country":["Europe","Wor ...
#     var render_items = [{"docid":"8c098dca-a695-4853-be63-b9dfa119889d","root_ids":["1502"],"roots":{"1502":"24dccfe0-ed5f-433c-8339-a92b9b2aaf38"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # 3rd viz - CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='1552'>
#   <div class="bk-root" id="751166fa-ea33-49bc-956c-9f693c7b2c0a" data-root-id="1552"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"952b7234-ad8e-4cd0-89ba-c9afe0c6a48d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"bar_color":"darkgreen","end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year","value":2015},"id":"1556","type":"Slider"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer06526","sizing_mode":"stretch_width"},"id":"1557","type":"Spacer"},{"attributes":{"client_comm_id":"92fc5d4fc5ac4519b7190c53a7bbca67","comm_id":"407526e71e534f2fb57ad51102ac4980","plot_id":"1552"},"id":"1560","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1554"},{"id":"1558"}],"margin":[0,0,0,0],"name":"Column06528"},"id":"1553","type":"Column"},{"attributes":{"children":[{"id":"1559"}],"margin":[0,0,0,0],"name":"Row06449"},"id":"1558","type":"Row"},{"attributes":{"children":[{"id":"1553"}],"margin":[0,0,0,0],"name":"Row06529"},"id":"1552","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame06524","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;2015&lt;/td&gt;\n      &lt;td&gt;1824.377391&lt;/td&gt;\n      &lt;td&gt;7.904&lt;/td&gt;\n    &lt;/tr&gt;\n    ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='11479'>
#   <div class="bk-root" id="7f5620dd-1672-4eda-8d30-86390081bd38" data-root-id="11479"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"688fac1c-ac9e-4b73-bcc6-fcdbc71087f6":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"coordinates":null,"data_source":{"id":"13337"},"glyph":{"id":"13340"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"13342"},"nonselection_glyph":{"id":"13341"},"selection_glyph":{"id":"13345"},"view":{"id":"13344"}},"id":"13343","type":"GlyphRenderer"},{"attributes":{"coordinates":null,"data_source":{"id":"12041"},"glyph":{"id":"12044"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"12046"},"nonselection_glyph":{"id":"12045"},"selection_glyph":{"id":"12049"},"view":{"id":"12048"}},"id":"12047","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#30a2da"},"line_alpha":{"value":0.7},"line_color":{"value":"#30a2da"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"13062","type":"Scatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#d62728"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#d62728"},"line_alpha":{"value":0.7},"line_color":{"value":"#d62728"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"12044","type":"Scatter"},{"attributes":{"source":{"id":"13058"}},"id":"13065","type":"CDSView"},{"attributes":{},"id":"13972","type":"UnionRenderers"},{"attributes":{},"id":"14142","type":"UnionRenderers"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#30a2da"},"hatch ...

# %% [markdown]
# # 4th viz -  Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='18288'>
#   <div class="bk-root" id="a5dd1878-19e7-4417-8ace-a40220f880ea" data-root-id="18288"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f655ed6e-6c69-4305-a57c-354125c5e489":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"18290"},{"id":"18298"}],"margin":[0,0,0,0],"name":"Column65047"},"id":"18289","type":"Column"},{"attributes":{"axis":{"id":"18310"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"18313","type":"Grid"},{"attributes":{},"id":"18303","type":"CategoricalScale"},{"attributes":{"overlay":{"id":"18319"}},"id":"18317","type":"BoxZoomTool"},{"attributes":{},"id":"18311","type":"BasicTicker"},{"attributes":{"children":[{"id":"18289"}],"margin":[0,0,0,0],"name":"Row65048"},"id":"18288","type":"Row"},{"attributes":{"client_comm_id":"b21cf461be774c7090ac18c02354fe12","comm_id":"884340f03a4b4186910fff9cf3607982","plot_id":"18288"},"id":"18382","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"18291"},{"id":"18294"}],"margin":[0,0,0,0],"name":"Row65041"},"id":"18290","type":"Row"},{"attributes":{"children":[{"id":"18292"},{"id":"18293"}],"margin":[0,0,0,0],"name":"Column65036"},"id":"18291","type":"Column"},{"attributes":{},"id":"18328","type":"Selection"},{"attributes":{"active":0,"button_type":"success","labels":["coal_co2","oil_co2","gas_co2"],"margin":[5,10,5,10]},"id":"18293","type":"RadioButtonGroup"},{"attributes":{},"id":"18314","type":"SaveTool"},{"attributes":{"end":12253.071600000001,"reset_end":12253.071600000001,"reset_start":0.0,"tags":[[["coal_co2","coal_co2",null]]]},"id":"18296","type":"Range1d"},{"attributes" ...

# %% [markdown]
# # 5th - Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=500), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
